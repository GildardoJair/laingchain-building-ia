# %% [markdown]
# LanChaing proporciona cargadores de documentos que gestionan la lógica y permite cargar datosen una clase Document que consta de texto y metadatos

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("data/test.txt")
loader.load()
# Out:
# [Document(metadata={'source': 'data/test.txt'}, page_content='Hola este es un documento de prueba:\nAUTOR: POEMA DE SOR sJUAN INÉS DE LA CRUZ\nTITULO: Amor empieza por desasosiego\n\nAmor empieza por desasosiego,\nsolicitud, ardores y desvelos;\ncrece con riesgos, lances y recelos;\nsusténtase de llantos y de ruego.\n\nDoctrínanle tibiezas y despego,\nconserva el ser entre engañosos velos,\nhasta que con agravios o con celos\napaga con sus lágrimas su fuego.\n\nSu principio, su medio y fin es éste:\n¿pues por qué, Alcino, sientes el desvío\nde Celia, que otro tiempo bien te quiso?\n\n¿Qué razón hay de que dolor te cueste?\nPues no te engañó amor, Alcino mío,\nsino que llegó el término preciso')]

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader("https://www.langchain.com/")
loader.load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# ...

# %%
# install the pdf parsing library
# pip install pypdf
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("data/pruebamorelos.pdf")
pages = loader.load()
pages
# Out:
# [Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': 'PyPDF', 'creationdate': '2026-04-25T18:33:25-06:00', 'source': 'data/pruebamorelos.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content='Las cartas de MoreLos \ne n  L a  B i B L i o t e c a J o s è M a r ì a L a f r a g u a\nestudio introductorio\naLicia tecuanhuey sandovaL\nPaLeografìa\nMaría deL carMen aguiLar guzMán\nMisaeL aMaro guevara'),
#  Document(metadata={'producer': 'cairo 1.18.0 (https://cairographics.org)', 'creator': 'PyPDF', 'creationdate': '2026-04-25T18:33:25-06:00', 'source': 'data/pruebamorelos.pdf', 'total_pages': 8, 'page': 1, 'page_label': '2'}, page_content='Las Cartas de Morelos en la \nBiblioteca José María Lafragua, BUAP\nEstudio introductorio\nAlicia Tecuanhuey Sandoval'),
# ...
