# %%
from langchain_community.llms import Ollama
# 1. Inicializar el modelo Llama3 a través de Ollama
llm = Ollama(model="llama3.2")
# 2. Invocar el modelo
respuesta = llm.invoke("¿Qué es LangChain?")
print(respuesta)
# Out:
# LangChain es una biblioteca de código abierto escrita en Rust que proporciona una API para crear y gestionar cadenas de acciones (chains) en la blockchain. Las cadenas de acciones se refieren a conjuntos de transacciones relacionadas que pueden ser ejecutadas en conjunto, lo que ofrece beneficios como la seguridad, la eficiencia y la escalabilidad.
#
# LangChain es especialmente útil para desarrolladores de aplicaciones de blockchain que necesitan crear y gestionar cadenas de acciones complejas. Al utilizar LangChain, los desarrolladores pueden:
#
# 1. Crear y gestionar cadenas de acciones personalizadas.
# 2. Ejecutar transacciones relacionadas en conjunto.
# 3. Manejar la seguridad y la autenticidad de las transacciones.
#
# LangChain se puede integrar con diferentes protocolos de blockchain, como Ethereum, Polkadot y Solana, lo que lo hace una herramienta versátil para desarrolladores de blockchain.
#
# Algunas de las características clave de LangChain incluyen:
#
# * Aplicación modular: LangChain se divide en módulos separados que pueden ser utilizados por los desarrolladores.
# * API fácil de usar: La biblioteca proporciona una API simple y intuitiva para crear y gestionar cadenas de acciones.
# * Integración con protocolos de blockchain: LangChain se puede integrar con diferentes protocolos de blockchain, lo que permite a los desarrolladores utilizar sus características nativas.
#
# En resumen, LangChain es una herramienta poderosa para desarrolladores de blockchain que necesitan crear y gestionar cadenas de acciones complejas. Su capacidad para proporcionar una API fácil de usar y su integración con diferentes protocolos de blockchain la convierten en una opción atractiva para proyectos de blockchain en desarrollo.

# %%
from langchain_core.messages import HumanMessage

prompt = [HumanMessage("¿Cual es la cápital de Puebla?")]
llm.invoke(prompt)
# Out:
# 'Hola!\n\nLa respuesta a tu pregunta es: Cholula.\n\nCholula es una ciudad ubicada en el estado de Puebla, México. Es conocida por su rica historia, su patrimonio cultural y arquitectónico, y por ser el lugar donde se celebran algunas de las festividades más importantes del estado, como la Fiesta de la Vendimia.\n\nSin embargo, es importante mencionar que también hay otra ciudad llamada Puebla, que es la capital estatal de Puebla. La ciudad de Puebla es una de las más antiguas y bien conservadas del país, con una rica historia que abarca más de 700 años.\n\nEspero que esta información te haya sido útil. ¡Si tienes alguna otra pregunta, no dudes en preguntar!'

# %%
from langchain_core.messages import HumanMessage, SystemMessage

system_msg = SystemMessage(
'''You are a helpful assistant that responds to questions with three
exclamation marks.'''
)
human_msg = HumanMessage('What is the capital of France?')
llm.invoke([system_msg, human_msg])
# Out:
# '!!!Paris!!!'

# %%
from langchain_core.prompts import PromptTemplate
template = PromptTemplate.from_template("""Answer the question based on the
context below. If the question cannot be answered using the information
provided, answer with "I don't know".
Context: {context}
Question: {question}
Answer: """)
template.invoke({
"context": """The most recent advancements in NLP are being driven by Large
Language Models (LLMs). These models outperform their smaller
counterparts and have become invaluable for developers who are creating
applications with NLP capabilities. Developers can tap into these
models through Hugging Face's `transformers` library, or by utilizing
OpenAI and Cohere's offerings through the `openai` and `cohere`
libraries, respectively.""",
"question": "Which model providers offer LLMs?"
})
# Out:
# StringPromptValue(text='Answer the question based on the\ncontext below. If the question cannot be answered using the information\nprovided, answer with "I don\'t know".\nContext: The most recent advancements in NLP are being driven by Large\nLanguage Models (LLMs). These models outperform their smaller\ncounterparts and have become invaluable for developers who are creating\napplications with NLP capabilities. Developers can tap into these\nmodels through Hugging Face\'s `transformers` library, or by utilizing\nOpenAI and Cohere\'s offerings through the `openai` and `cohere`\nlibraries, respectively.\nQuestion: Which model providers offer LLMs?\nAnswer: ')

# %%
from langchain_core.prompts import PromptTemplate
# both `template` and `model` can be reused many times
template = PromptTemplate.from_template("""Answer the question based on the
context below. If the question cannot be answered using the information
provided, answer with "I don't know".
Context: {context}
Question: {question}
Answer: """)
# `prompt` and `completion` are the results of using template and model once
prompt = template.invoke({
"context": """The most recent advancements in NLP are being driven by Large
Language Models (LLMs). These models outperform their smaller
counterparts and have become invaluable for developers who are creating
applications with NLP capabilities. Developers can tap into these
models through Hugging Face's `transformers` library, or by utilizing
OpenAI and Cohere's offerings through the `openai` and `cohere`
libraries, respectively.""",
"question": "Which model providers offer LLMs?"
})
completion = llm.invoke(prompt)
completion
# Out:
# 'Hugging Face and OpenAI.'

# %%
from langchain_core.prompts import ChatPromptTemplate
template = ChatPromptTemplate.from_messages([
('system', '''Answer the question based on the context below. If the
question cannot be answered using the information provided, answer with
"I don\'t know".'''),
('human', 'Context: {context}'),
('human', 'Question: {question}'),
])
template.invoke({
"context": """The most recent advancements in NLP are being driven by Large
Language Models (LLMs). These models outperform their smaller
counterparts and have become invaluable for developers who are creating
applications with NLP capabilities. Developers can tap into these
models through Hugging Face's `transformers` library, or by utilizing
OpenAI and Cohere's offerings through the `openai` and `cohere`
libraries, respectively.""",
"question": "Which model providers offer LLMs?"
})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Answer the question based on the context below. If the\nquestion cannot be answered using the information provided, answer with\n"I don\'t know".', additional_kwargs={}, response_metadata={}), HumanMessage(content="Context: The most recent advancements in NLP are being driven by Large\nLanguage Models (LLMs). These models outperform their smaller\ncounterparts and have become invaluable for developers who are creating\napplications with NLP capabilities. Developers can tap into these\nmodels through Hugging Face's `transformers` library, or by utilizing\nOpenAI and Cohere's offerings through the `openai` and `cohere`\nlibraries, respectively.", additional_kwargs={}, response_metadata={}), HumanMessage(content='Question: Which model providers offer LLMs?', additional_kwargs={}, response_metadata={})])
